# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import SVC
import joblib

# %% [markdown]
# # Load data

# %%
def load_data():
    data = pd.read_csv("data/SMSSpamCollection.csv")
    data.columns = ["label", "message"]  # ensure correct columns
    return data

# %% [markdown]
# # Preprocessing

# %%
def preprocess(df):
    x = df["message"]
    y = df["label"]
    vect = TfidfVectorizer(lowercase=True, stop_words="english", ngram_range=(1,2), min_df=2, sublinear_tf=True)
    x_vect = vect.fit_transform(x)
    return x_vect, y, vect

# %% [markdown]
# # Train model

# %%
def train_model(x, y, vect):
    model_svc = SVC(C=1, kernel="linear")
    model_svc.fit(x, y)
    joblib.dump(model_svc,"Sms_spam_detection_model.pkl")    
    joblib.dump(vect, "tfidf_vectorizer.pkl")
    print("Model and vectorizer saved!")

# %% [markdown]
# # Main

# %%
def main():
    df = load_data()
    x_vect, y, vect = preprocess(df)
    train_model(x_vect, y, vect)

# %%
if __name__ == "__main__":
    main()
# Out:
# Model and vectorizer saved!
